# %%
#1.1 Setup - module import/other setup
from __future__ import division

# %pylab
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,12)
import sys
import scipy.signal
import json
import pandas
import csv
from collections import OrderedDict, defaultdict
print
print ('\nModule Import Successful')
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
#
# Module Import Successful

# %%
path = "data/"
filename = "life_ASM1887_2.0lpm_.4d_2020-03-16_154139"
extension = ".csv"

# %%
df = pandas.read_csv(path + filename + extension)
df.keys()
# Out:
# Index(['timestamp', 'elapsed_time', 'NO', 'NO2', 'MFC.pressure', 'MFC.temp',
#        'MFC.mass_flow', 'MFC.setpoint', 'GDN.Vin', 'GDN.Iin', 'GDN.PlasmaDuty',
#        'GDN.Vreg', 'SHT31.temp', 'SHT31.humid', 'Sweep.GDN.PlasmaDuty',
#        'Sweep.MFC.setpoint', 'Settled', 'Sweep.StepNum', 'read_err'],
#       dtype='object')

# %%
figure()
plot((df['elapsed_time']/3600)[0:100], df['NO'][0:100], label = 'NO', color='red')
#plot(df['elapsed_time'], df['NO'], label = 'NO2', color='blue')
xlabel('ppm')
ylabel('time(hr)')
# Out:
# Text(0, 0.5, 'time(hr)')
