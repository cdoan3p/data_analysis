# %%
#1.1 Setup - module import/other setup

# %pylab
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,12)
from __future__ import division
import sys
import scipy.signal
import json
import pandas
import csv
from collections import OrderedDict, defaultdict
print
print 'Module Import Successful'
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
#
# Module Import Successful

# %%
path = "data/"
filename = "life_ASM1887_2.0lpm_.4d_2020-03-16_154139"
extension = ".csv"

# %%
df = pandas.read_csv(path + filename + extension)
df.keys()
# Out:
# Index([u'timestamp', u'elapsed_time', u'NO', u'NO2', u'MFC.pressure',
#        u'MFC.temp', u'MFC.mass_flow', u'MFC.setpoint', u'GDN.Vin', u'GDN.Iin',
#        u'GDN.PlasmaDuty', u'GDN.Vreg', u'SHT31.temp', u'SHT31.humid',
#        u'Sweep.GDN.PlasmaDuty', u'Sweep.MFC.setpoint', u'Settled',
#        u'Sweep.StepNum', u'read_err'],
#       dtype='object')

# %%
figure()
plot((df['elapsed_time']/3600)[0:100], df['NO'][0:100], label = 'NO', color='red')
#plot(df['elapsed_time'], df['NO'], label = 'NO2', color='blue')
xlabel('ppm')
ylabel('time(hr)')
# Out:
# Text(0,0.5,'time(hr)')
